# %% [markdown]
# <a href="https://colab.research.google.com/github/andreidore/deep-rl-tf2/blob/master/dqn/dqn_miniworld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# !apt-get install python-opengl -y
# !apt install xvfb -y
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:6 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [8,213 B]
# Get:7 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [889 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [44.6 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [839 kB]
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [89.3 kB]
# ...

# %%
# !pip install wandb
# !pip install pyvirtualdisplay
# !pip install piglet
# !pip install gym
# !pip install git+https://github.com/maximecb/gym-miniworld
# Out:
# ...
#      |████████████████████████████████| 1.4MB 2.7MB/s
# ...
#      |████████████████████████████████| 102kB 11.0MB/s
# ...
#      |████████████████████████████████| 102kB 10.3MB/s
# ...
#      |████████████████████████████████| 460kB 32.2MB/s
# ...
#      |████████████████████████████████| 112kB 43.8MB/s
# ...
#      |████████████████████████████████| 71kB 8.2MB/s
# ...
#      |████████████████████████████████| 71kB 8.9MB/s
# ...
#   Created wheel for gql: filename=gql-0.2.0-cp36-none-any.whl size=7630 sha256=4237ae9fb59d9f9ff65cd96ae2a9f2d2af5d0329181950c8328951d8648e7c15
#   Stored in directory: /root/.cache/pip/wheels/ce/0e/7b/58a8a5268655b3ad74feef5aa97946f0addafb3cbb6bd2da23
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp36-none-any.whl size=6489 sha256=7de9855aef9a1d560513e2adc6db997fd548cf705f32a25c652d06ce4ed623d3
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
# ...

# %%
# !git clone https://github.com/maximecb/gym-miniworld
# Out:
# Cloning into 'gym-miniworld'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 6952 (delta 22), reused 22 (delta 9), pack-reused 6910
# Receiving objects: 100% (6952/6952), 136.82 MiB | 36.21 MiB/s, done.
# Resolving deltas: 100% (1903/1903), done.

# %%
# %ls -lA gym-miniworld/
# Out:
# total 72
# -rwxr-xr-x 1 root root   936 Apr 28 20:09 benchmark.py*
# drwxr-xr-x 2 root root  4096 Apr 28 20:09 docs/
# drwxr-xr-x 2 root root  4096 Apr 28 20:09 experiments/
# drwxr-xr-x 8 root root  4096 Apr 28 20:09 .git/
# -rw-r--r-- 1 root root  1223 Apr 28 20:09 .gitignore
# drwxr-xr-x 5 root root  4096 Apr 28 20:09 gym_miniworld/
# drwxr-xr-x 2 root root  4096 Apr 28 20:09 images/
# -rw-r--r-- 1 root root 11355 Apr 28 20:09 LICENSE
# -rwxr-xr-x 1 root root  2464 Apr 28 20:09 manual_control.py*
# drwxr-xr-x 5 root root  4096 Apr 28 20:09 pytorch-a2c-ppo-acktr/
# -rw-r--r-- 1 root root  4811 Apr 28 20:09 README.md
# -rwxr-xr-x 1 root root  1928 Apr 28 20:09 run_tests.py*
# drwxr-xr-x 2 root root  4096 Apr 28 20:09 scripts/
# -rw-r--r-- 1 root root   371 Apr 28 20:09 setup.py
# -rw-r--r-- 1 root root   797 Apr 28 20:09 .travis.yml

# %%
# %cp -r gym-miniworld/gym_miniworld/textures /usr/local/lib/python3.6/dist-packages/gym_miniworld/textures 
# %cp -r gym-miniworld/gym_miniworld/meshes/ /usr/local/lib/python3.6/dist-packages/gym_miniworld/meshes

# %%
# !ls -lA /usr/local/lib/python3.6/dist-packages/gym_m*
# Out:
# /usr/local/lib/python3.6/dist-packages/gym_miniworld:
# total 124
# -rw-r--r-- 1 root staff 12452 Apr 28 20:08 entity.py
# drwxr-sr-x 3 root staff  4096 Apr 28 20:08 envs
# -rw-r--r-- 1 root staff   189 Apr 28 20:08 __init__.py
# -rw-r--r-- 1 root staff  1392 Apr 28 20:08 math.py
# drwxr-sr-x 2 root staff  4096 Apr 28 20:09 meshes
# -rw-r--r-- 1 root staff 40847 Apr 28 20:08 miniworld.py
# -rw-r--r-- 1 root staff  8878 Apr 28 20:08 objmesh.py
# -rw-r--r-- 1 root staff 13517 Apr 28 20:08 opengl.py
# -rw-r--r-- 1 root staff  3924 Apr 28 20:08 params.py
# drwxr-sr-x 2 root staff  4096 Apr 28 20:08 __pycache__
# -rw-r--r-- 1 root staff  1404 Apr 28 20:08 random.py
# drwxr-sr-x 4 root staff  4096 Apr 28 20:09 textures
# -rw-r--r-- 1 root staff  1005 Apr 28 20:08 utils.py
# -rw-r--r-- 1 root staff  1296 Apr 28 20:08 wrappers.py
#
# /usr/local/lib/python3.6/dist-packages/gym_miniworld-2018.8.1.dist-info:
# total 36
# -rw-r--r-- 1 root staff     4 Apr 28 20:08 INSTALLER
# ...

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# xdpyinfo was not found, X start can not be checked! Please install xdpyinfo!
# <Display cmd_param=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1001'] cmd=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1001'] oserror=None return_code=None stdout="None" stderr="None" timeout_happened=False>

# %%
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1

# %%
import os
import gym
import gym_miniworld
from gym_miniworld.wrappers import *
# %matplotlib inline
import matplotlib.pyplot as plt
import base64
import io
import os
import glob
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only
import random
from collections import deque
import tensorflow as tf
import numpy as np
from IPython.display import HTML
from IPython import display as ipythondisplay
import wandb

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test"  
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
from gym import envs

print(envs.registry.all())
# Out:
# dict_values([EnvSpec(Copy-v0), EnvSpec(RepeatCopy-v0), EnvSpec(ReversedAddition-v0), EnvSpec(ReversedAddition3-v0), EnvSpec(DuplicatedInput-v0), EnvSpec(Reverse-v0), EnvSpec(CartPole-v0), EnvSpec(CartPole-v1), EnvSpec(MountainCar-v0), EnvSpec(MountainCarContinuous-v0), EnvSpec(Pendulum-v0), EnvSpec(Acrobot-v1), EnvSpec(LunarLander-v2), EnvSpec(LunarLanderContinuous-v2), EnvSpec(BipedalWalker-v3), EnvSpec(BipedalWalkerHardcore-v3), EnvSpec(CarRacing-v0), EnvSpec(Blackjack-v0), EnvSpec(KellyCoinflip-v0), EnvSpec(KellyCoinflipGeneralized-v0), EnvSpec(FrozenLake-v0), EnvSpec(FrozenLake8x8-v0), EnvSpec(CliffWalking-v0), EnvSpec(NChain-v0), EnvSpec(Roulette-v0), EnvSpec(Taxi-v3), EnvSpec(GuessingGame-v0), EnvSpec(HotterColder-v0), EnvSpec(Reacher-v2), EnvSpec(Pusher-v2), EnvSpec(Thrower-v2), EnvSpec(Striker-v2), EnvSpec(InvertedPendulum-v2), EnvSpec(InvertedDoublePendulum-v2), EnvSpec(HalfCheetah-v2), EnvSpec(HalfCheetah-v3), EnvSpec(Hopper-v2), EnvSpec(Hopper-v3), EnvSpec(Swimmer-v2), Env
# ...

# %%
env = wrap_env(gym.make("MiniWorld-ThreeRooms-v0"))
#env = gym.make("MiniWorld-Hallway-v0")

observation = env.reset()

while True:
  
    env.render()
    
    #your agent goes here
    action = env.action_space.sample() 
         
    observation, reward, done, info = env.step(action) 
   
        
    if done: 
      break;
            
env.close()
show_video()
# Out:
# Falling back to num_samples=1
# Falling back to num_samples=1
# <video alt="test"
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
